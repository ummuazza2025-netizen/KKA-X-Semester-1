# %% [markdown]
# <a href="https://colab.research.google.com/github/ummuazza2025-netizen/KKA-X-Semester-1/blob/main/App_Bangun_Balok_Azza_U_Z_X_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama Kelompok : Ayam Terbang
# Nama Panjang : Azza Ummu Zahro
# Kelas : X. 5
# No.Absen : 10

# %% [markdown]
# App Bangun Balok

# %%
# Program menghitung volume balok

#Meminta input dari pengguna
panjang = float(input("Masukkan panjang balok (cm): "))
lebar = float(input("Masukkan lebar balok (cm): "))
tinggi = float(input("Masukkan tinggi balok (cm): "))

#Menghitung volume
volume = panjang * lebar * tinggi

#Menampilkan hasil
print(f"Volume balok adalah:{volume} cm^3.")
# Out:
# Masukkan panjang balok (cm): 5
# Masukkan lebar balok (cm): 3
# Masukkan tinggi balok (cm): 2
# Volume balok adalah:30.0 cm^3.
