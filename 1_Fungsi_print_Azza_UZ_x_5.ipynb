# %% [markdown]
# <a href="https://colab.research.google.com/github/ummuazza2025-netizen/KKA-X-Semester-1/blob/main/1_Fungsi_print_Azza_UZ_x_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. Menampilkan Teks Bebas

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("Azza Ummu Zahro")
# Out:
# Azza Ummu Zahro

# %% [markdown]
# #2. Menampilkan Nilai Variabel

# %%
beratbadan = 50

print(beratbadan)
# Out:
# 50

# %%
Nama = "Azza ummu zahro"


print(Nama)
# Out:
# Azza ummu zahro

# %%
tinggibadan = 160

print(tinggibadan)
# Out:
# 160

# %%
Nama = "kim sunoo"

print(Nama)
# Out:
# kim sunoo

# %% [markdown]
# #3. Menampilkan Teks Bebas dan Nilai Variabel

# %%
print("Halo nama Saya", Nama,". Berat badan Saya",beratbadan,"kg.")
# Out:
# Halo nama Saya Azza ummu zahro . Berat badan Saya 50 kg.

# %%
print("Halo nama Saya "+ Nama+". Berat badan Saya "+str(beratbadan)+" kg.")
# Out:
# Halo nama Saya Azza ummu zahro. Berat badan Saya 50 kg.

# %%
print(f"Halo nama Saya {Nama}. Berat badan Saya {beratbadan} kg.")
# Out:
# Halo nama Saya Azza ummu zahro. Berat badan Saya 50 kg.

# %% [markdown]
# #4. Escape Character

# %%
print("Nama:Azza ummu Zahro")
print("Kelas: X.5")
print("No.Absen:10")
# Out:
# Nama:Azza ummu Zahro
# Kelas: X.5
# No.Absen:10

# %%
print("Nama: Azza ummu Zahro\nKelas: X-5\nNo. Absen: 10")
# Out:
# Nama: Azza ummu Zahro
# Kelas: X-5
# No. Absen: 10

# %%
print("""Nama\t\t: Azza Ummu Zahro
Kelas\t\t: X-5
No. Absen\t: 10""")
# Out:
# Nama		: Azza Ummu Zahro
# Kelas		: X-5
# No. Absen	: 10

# %%
print('Nama Saya Ja\'far Shodiq')
# Out:
# Nama Saya Ja'far Shodiq

# %%
print("Nama Saya Ja'far Shodiq")
# Out:
# Nama Saya Ja'far Shodiq

# %%
print("Nama Saya Ja\'far Shodiq")
# Out:
# Nama Saya Ja'far Shodiq

# %%
print('Bu Shinta berkata, "Tolong perhatikan TV dan Saya."')
# Out:
# Bu Shinta berkata, "Tolong perhatikan TV dan Saya."

# %%
print("Bu Shinta berkata, \"Tolong perhatikan TV dan Saya.\"")
# Out:
# Bu Shinta berkata, "Tolong perhatikan TV dan Saya."

# %%
print("Lokasi file tugas KKA adalah di Local Disk C:\\KKA\\Tugas")
# Out:
# Lokasi file tugas KKA adalah di Local Disk C:\KKA\Tugas

# %% [markdown]
# #5. PARAMETER FUNGSI PRINT

# %%
nama_siswa_1 = "Jielo"
nama_siswa_2 = "Aida"
nama_siswa_3 = "Dani"
nama_siswa_4 = "Nurul"

print(nama_siswa_1, end="/")
print(nama_siswa_2, end="/")
print(nama_siswa_3, end="/")
print(nama_siswa_4)
# Out:
# Jielo/Aida/Dani/Nurul

# %%
nama_siswa_5 = "Hasbi"
nama_siswa_6 = "Habibi"
nama_siswa_7 = "Rendra"
nama_siswa_8 = "Naufal"

print(nama_siswa_8, nama_siswa_7, nama_siswa_6, nama_siswa_5, sep="*")
# Out:
# Naufal*Rendra*Habibi*Hasbi

# %%
nama_siswa_5 = "Hasbi"
nama_siswa_6 = "Habibi"
nama_siswa_7 = "Rendra"
nama_siswa_8 = "Naufal"

print(nama_siswa_8, nama_siswa_7, nama_siswa_5, nama_siswa_6, sep="-")
# Out:
# Naufal-Rendra-Hasbi-Habibi

# %%
nama_siswa_1= "Jielo"
nama_siswa_2= "Aida"
nama_siswa_3= "Dani"

print(nama_siswa_1,end= "-")
print(nama_siswa_2,end= "-")
print(nama_siswa_3)
# Out:
# Jielo-Aida-Dani

# %%
nama_siswa_5 = "Hasbi"
nama_siswa_6 = "Habibi"
nama_siswa_7 = "Rendra"
nama_siswa_8 = "Naufal"

# %%
print(nama_siswa_5,nama_siswa_8,nama_siswa_7,nama_siswa_6
